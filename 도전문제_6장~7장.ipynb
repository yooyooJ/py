# %% [markdown]
# <a href="https://colab.research.google.com/github/yooyooJ/py/blob/main/%EB%8F%84%EC%A0%84%EB%AC%B8%EC%A0%9C_6%EC%9E%A5~7%EC%9E%A5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#도전문제6장

#도전문제 6-1 (turtle grapic)
#import turtle
#t = turtle.Turtle()
#t.shape("turtle")
#for i in range(6):
#   t.forward(100)
#   t.left(360/6)
#s = tuetle.textinput("","몇각형을 원하시나요?: ")
#n = int(s)
#s = turtle.textinput("","한 변의 크기를 입력해주세요: ")
#len = int(s)
#for i in range(n):
#   t.forward(len)
#   t.left(360/n)

#도전문제 6-2 (turtle grapic)
#import turtle
#import random
#t = turtle.Turtle()
#t.shape("turtle")
#for i in range(30):
#   length = random.randint(1,100)
#   t.forward(length)
#   angle = random.randint(1,4)
#   t.right(90*angle)

#도전문제 6-3
i = 1
while i <= 9:
  j = 1 #곱할 값
  while j <=9: #9*9 달성 -> 반복루프 벗어남
    print(i, "*", j, "=", i*j)
    j = j+1
  print(" ")
  i = i+1

#도전문제 6-4 (turtle grapic)
#import turtle
#t = turtle.Turtle()
#t.shape("turtle")
#i = 0
#while i < 5:
#   t.forward(50)
#   t.right(144)

#도전문제 6-5 (turtle grapic)
#import turtle
#import random
#colors = ["red", "purple", "blue", "green", "yellow", "orange"]
#t = turtle.Turtle()
#turtle.bgcolor("black")        #배경색 변경
#t.speed(0)       #속도 변경
#t.width(3)       #선 두께
#length = 10
#while length < 500:
#   t.forward(length)
#   t.pencolor(colors[length%6])
#   angle = random.randint(1,100)
#   t.right(angle)
#   length += 5

#도전문제 6-6
import random
tries = 0
guess = 0
answer = random.randint(1,100)
print("1부터 100 사이의 숫자를 맞추시오: ")
while guess != answer:
  if tries < 10:
    guess = int(input("숫자를 입력하시오: "))
    tries = tries + 1
    if guess < answer:
      print("낮음!")
    elif guess > answer:
      print("높음!")
  else:
    print("시도횟수를 초과하였습니다.")
    break
if guess == answer:
  print("축하합니다. 시도횟수= ", tries)
else:
  print("정답은", answer)

#도전문제 6-7
import random
while True:
  q = random.randint(0,1)
  x = random.randint(1,100)
  y = random.randint(1,100)
  if (q == 1) & (x > y):
    print(x, "-", y, "=", end= " ")
    answer == int(input())
    if answer == x - y:
      print("잘했어요!")
    else:
      print("다음번에는 잘할 수 있죠?")
  else:
    print(x, "+", y, "=", end= " ")
    answer = int(input())
    if answer == x + y:
      print("잘했어요!")
    else:
      print("다음번에는 잘할 수 있죠?")

#도전문제 6-8
import random
number = random.randint(1,8)
list = ["한 점의 의심도 없이 맞습니다.", "할 수 있습니다.", "물론입니다", "글쎄요. 열심히 해야 할 것입니다.", "안 될 것 같습니다.", "조금 더 노력하세요.", "행운을 빕니다.", "다음 달에 할 수 있을 겁니다."]
while True:
  name = input("이름: (종료하려면 엔터키)")
  if name == '':
    break;
  question = input("무엇에 대하여 알고 싶은가요?")
  print(name, "님", "\"",question, "\"에 대하여 질문 주셨군요.")
  print("운명의 주사위를 굴려볼게요...")
  print("list[number-1")
# Out:
# 1 * 1 = 1
# 1 * 2 = 2
# 1 * 3 = 3
# 1 * 4 = 4
# 1 * 5 = 5
# 1 * 6 = 6
# 1 * 7 = 7
# 1 * 8 = 8
# 1 * 9 = 9
#
# 2 * 1 = 2
# 2 * 2 = 4
# 2 * 3 = 6
# 2 * 4 = 8
# 2 * 5 = 10
# 2 * 6 = 12
# 2 * 7 = 14
# 2 * 8 = 16
# 2 * 9 = 18
#
# 3 * 1 = 3
# 3 * 2 = 6
# 3 * 3 = 9
# 3 * 4 = 12
# 3 * 5 = 15
# 3 * 6 = 18
# 3 * 7 = 21
# 3 * 8 = 24
# 3 * 9 = 27
#
# 4 * 1 = 4
# 4 * 2 = 8
# 4 * 3 = 12
# 4 * 4 = 16
# 4 * 5 = 20
# 4 * 6 = 24
# 4 * 7 = 28
# 4 * 8 = 32
# 4 * 9 = 36
#
# 5 * 1 = 5
# 5 * 2 = 10
# 5 * 3 = 15
# 5 * 4 = 20
# 5 * 5 = 25
# 5 * 6 = 30
# 5 * 7 = 35
# 5 * 8 = 40
# 5 * 9 = 45
#
# 6 * 1 = 6
# 6 * 2 = 12
# 6 * 3 = 18
# 6 * 4 = 24
# 6 * 5 = 30
# 6 * 6 = 36
# 6 * 7 = 42
# 6 * 8 = 48
# 6 * 9 = 54
#
# 7 * 1 = 7
# 7 * 2 = 14
# 7 * 3 = 21
# 7 * 4 = 28
# 7 * 5 = 35
# 7 * 6 = 42
# 7 * 7 = 49
# 7 * 8 = 56
# 7 * 9 = 63
#
# 8 * 1 = 8
# 8 * 2 = 16
# 8 * 3 = 24
# 8 * 4 = 32
# 8 * 5 = 40
# 8 * 6 = 48
# 8 * 7 = 56
# 8 * 8 = 64
# 8 * 9 = 72
#
# 9 * 1 = 9
# 9 * 2 = 18
# 9 * 3 = 27
# 9 * 4 = 36
# 9 * 5 = 45
# ...

# %%
#도전문제 7장

#도전문제 7-1 (turtle grapic)
#import turtle
#t = turtle.Turtle()
#t.shape("turtle")
#def shape(length):   #length는 한 변의 길이
#   s = turtle.textinput("","몇 각형을 원하시나요?: ")
#   n = int(s)
#   f i in range(n):
#     t.forward(length)
#     t.left(350/n)
#t.up()
#t.goto(-200,0)
#t.down()
#shape(100);
#t.up()
#t.goto(0,0)
#t.down()
#shape(100);
#t.up()
#t.goto(200,0)
#t.down()
#shape(100);

#도전문제 7-2 (turtle grapic)
#import turtle
#t = turtle.Turtle()
#t.shape("turtle")
#def squre(length,index):
#   t.color(colorList[index])
#   t.begin_fill()
#   for i in range(4):
#     t.forward(length)
#     t.left(90)
#   t.end_fill()
#colorList = ["red", "blue", "green"]
#x = -200
#for i in range(len(colorList)):
#   t.up()
#   t.goto(x,0)
#   t.down()
#   squre(100,i);
#   x+=200

#도전문제 7-3 (turtle grapic)
#import turtle
#t = turtle.Turtle()
#def n_polygon(n,length):     #n각형을 그리는 함수 정의
# for i in range(n):
#   t.forward(length)
#   t.left(360/n)
#def get_color(index):
#   list = ["red", "orange", "yellow", "green", "blue", "nazy", "purple", "gray", "skyblue", "pink"]
#   t.color(list[index])
#   t.begin_fill()
#   n_polygin(6,100)
#   t.end_fill()
#for i in range(10):
#   t.left(20)
#   get_color(i)

#도전문제 7-4 (turtle grapic)
#import turtle
#t = turtle.Turtle()
#def circle(length):
#   t.circle(length)
#   t.left(60)
#def drawit(x, y):
#   t.penup()
#   t.goto(x, y)
#   t.pemdown()
#   t.begin_fill()
#   t.color("green")
#   circle(50)
#   t.end_fill()
#s = turtle_Screen()      #그림이 그려지는 화면을 얻는다.
#s.onscreenclick(drawit)  #마우스 클릭 이벤트 처리 함수를 등록한다.

#도전문제 7-5 (turtle grapic)
#import turtle
#def tree(length):
# angle = (random.randint(-20,20))
# if length > 5:
#   t.forward(Length)
#   t.right(20 + angle)   #오른쪽으로 랜덤한 각도만큼 회전
#   tree(length-15*(random.random()+0.4))
#   t.left(40 + (angle * 2))
#   tree(length-15*(random.random()+0.4))
#   t.right(20 + angle)
#   t.backward(length)    #length만큼 뒤로 갔다 제자리로 돌아온다.
#t = turtle.Turtle()
#t.left(90)
#t.color("green")
#t.speed(1)
#tree(90)
