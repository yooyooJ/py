# %% [markdown]
# <a href="https://colab.research.google.com/github/yooyooJ/py/blob/main/%EC%97%B0%EC%8A%B5%EB%AC%B8%EC%A0%9C_1~5%EC%9E%A5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#연습문제1장

#1) "환영합니다.", "파이썬의 세계에 오신 것을 환영합니다.", "파이썬은 강력합니다." 출력
print("환영합니다.")
print("파이썬의 세계에 오신 것을 환영합니다.")
print("파이썬은 강력합니다.")

#2) 다음 프로그램의 실행 결과
print("반갑습니다. 파이썬!")            #반갑습니다. 파이썬!
print("2*3/10")                         #0.6
print("Hello", "World!", "!!!")         #Hello World !!!

#3) 한 주가 몇 시간에 해당하는 계산
print(7*24)  #일주일=7일, 하루=24 둘을 곱해준다.

#4~9는 터틀 그래픽이라 colab으로 실행 불가

#4)
#import turtle
#t = turtle.Turtle()
#t.shape("turtle")
#t.forward(100)
#t.left(90)
#t.forward(100)
#t.right(90)
#t.forward(100)
#t,right(90)
#t.forward(100)
#t.left(90)
#t.forward(100)
#t._screen.exitonclick()                          #화면을 마우스로 클릭해야 종료되게 하는 부분

#5) 두께가 10인 선 그리기
#import turtle
#t = turtle.Turtle()
#t.shape("turtle")
#width(10)                              #굵기 변경
#t.forward(100)
#t.left(90)
#t.forward(100)
#exitinclick()

#6) 선 색 바꾸기
#import turtle
#t = turtle.Turtle()
#t.shape("turtle")
#t.color("blue")                        #색 변경
#t.forward(100)
#t._screen.eixtonclick()

#7) 모양 바꾸기
#import turtle
#t = turtle.Turtle()
#t.shape("turtle")
#t.shape("square")                      #모양 변경
#t.forward(100)
#t._screen.exitonclick()

#8)
#import turtle
#t = turtle.Turtle()
#t.shape("turtle")
#t.up()
#t.goto(0, 0)
#t.down()
#t.forward(100)
#t.up()
#t.goto(0, 100)
#t.down()
#t.forward(100)
#t._screen.exitonclick()

#9) 오륜기 그리기
#import turtle
#t = turtle.Turtle()
#t.shape("turtle")
#t.up(); t,goto(-150, 0); t.down(); t.circle(80)
#t.up(); t,goto(0, 0); t.down(); t.circle(80)
#t.up(); t,goto(150, 0); t.down(); t.circle(80)
#t.up(); t,goto(-80, -100); t.down(); t.circle(80)
#t.up(); t,goto(80, -100); t.down(); t.circle(80)
#t._screen.exitonclick()
# Out:
# 환영합니다.
# 파이썬의 세계에 오신 것을 환영합니다.
# 파이썬은 강력합니다.
# 반갑습니다. 파이썬!
# 2*3/10
# Hello World! !!!
# 168

# %%
#연습문제2장

#1) 나이를 입력받고 사용자 나이가 100살이 되는 연도 출력
name = input("이름을 입력하시오: ")
age = int(input("나이를 입력하시오: "))
year = 2021-age+100
print(name+"씨는"+str(year)+"년에 100살이시네요!")

#2) 3개의 숫자를 받아서 평균 계산
n1 = int(input("첫 번째 숫자를 입력하시오: "))
n2 = int(input("두 번째 숫자를 입력하시오: "))
n3 = int(input("세 번째 숫자를 입력하시오: "))
average = (n1 + n2 + n3) / 3
print(n1, n2, n3, "의 평균은", average, "입니다.")

#3) 반지름을 입력받아 원의 면적 계산
radius = int(input("반지름을 입력하시오: "))
area = 3.141592 * radius *radius
print("반지름이", radius, "인 원의 넓이 =", area, "입니다.")

#4~7은 터틀 그래픽이라 colab으로 실행 불가

#4) 반지름을 저장하고 변수를 증가하면서 원 3개 그리자
#import turtle
#t = turtle.Turtle()
#t.shape("turtle")
#radius=50
#t.up()
#t.goto(0, 0)
#t.down()
#t.circle(radius)
#radius = radius + 20
#t.up()
#t.goto(100, 0)
#t.down()
#t.circle(radius)
#radius = radius + 20
#t.up()
#t.goto(200, 0)
#t.down()
#t.circle(radius)
#t._screen.exitonclick()

#5) side 변수를 이용하여 삼각형을 그리자
#import turtle
#t = turtle.Turtle()
#t.shape("turtle")
#side=50
#t.forward(side)
#t.left(120)
#t.forward(side)
#t.left(120)
#t.forward(side)
#t.left(120)
#t._screen.exitonclick()

#6) 5의 코드에서 수정하여 한 변의 길이가 200인 삼각형
#import turtle
#t = turtle.Turtle()
#t.shape("turtle")
#side=200
#t.forward(side)
#t.left(120)
#t.forward(side)
#t.left(120)
#t.forward(side)
#t.left(120)
#t._screen.exitonclick()

#7) side 변수와 angle 변수에 값을 저장하여 창문 그림 그리기
#import turtle
#t = turtle.Turtle()
#t.shape("turtle")
#side = 50
#angle = 90
#t.forward(side); t.right(angle); t.forward(side); t.right(angle); t.forward(side); t.right(angle); t.forward(side)
#t.forward(side); t.right(angle); t.forward(side); t.right(angle); t.forward(side)
#t.right(angle); t.forward(100); t,right(180)
#t.forward(side); t.right(angle); t.forward(side); t.right(angle); t.forward(side) t.right(angle); t,.forward(side)
#t.forward(side); t.right(angle); t.forward(side); t.right(angle); t.forward(side)
#t.write("닫으려면 화면 클릭"); t._screen.exitonclick()
# Out:
# 이름을 입력하시오: 한유정
# 나이를 입력하시오: 20
# 한유정씨는2101년에 100살이시네요!
# 첫 번째 숫자를 입력하시오: 6
# 두 번째 숫자를 입력하시오: 7
# 세 번째 숫자를 입력하시오: 5
# 6 7 5 의 평균은 6.0 입니다.
# 반지름을 입력하시오: 50
# 반지름이 50 인 원의 넓이 = 7853.98 입니다.

# %%
#연습문제3장

#1) 두 개의 정수를 받아 합, 차, 곱, 평균, 큰 수, 작은 수 출력
x = int(input("x: "))
y = int(input("y: "))
print("두 수의 합: ", x+y)
print("두 수의 차: ", x-y)
print("두 수의 곱: ", x*y)
print("두 수의 평균: ", (x+y)/2)
print("큰 수: ", max(x, y))
print("직은 수: ", min(x, y))

#2) 원기둥 부피를 계산
r = float(input("r: "))
h = float(input("h: "))
vol = 3.141592*r**2*h
print("원기둥의 부피: ", vol)

#3) 정수의 자리수의 합 계산
number = int(input("정수를 입력하시오: "))
sum = 0
sum = sum + number % 10
number = number // 10
sum = sum + number %10
number = number // 10
sum = sum + number % 10
number = number // 10
sum = sum + number %10
number = number // 10
print("자리수의 합: ", str(sum))

#4) 두 점의 좌표를 입력받아 두 점 사이의 거리 계산
x1 = int(input("x1: "))
y1 = int(input("y1: "))
x2 = int(input("x2: "))
y2 = int(input("y2: "))
dist = ((x2-x1)**2+(y2-y1)**2)**0.5
print("두 점 사이의 거리=", dist)

#5~6은 터틀 그래픽이라 colab으로 실행 불가

#5)
#import math
#x1 = int(input("x1: "))
#y1 = int(input("y1: "))
#x2 = int(input("x2: "))
#y2 = int(input("y2: "))
#dist = math.sqrt((x2-x1)**2+(y2-y1)**2)
#print("두 점 사이의 거리=",dist)
#import turtle
#t = turtle.Turtle()
#t.shape("turtle")
#t.left(45)
#t.forward(141)
#t.setheading(0)
#t.goto(0, 0)
#t.forward(100)
#t.left(90)
#t.forward(100)
#t._screen.exitonclick()

#6) 두 점을 입력받아 연결하는 직선을 그리고 직선의 끝점에 직선의 길이를 계산하여 출력
#inport turtle
#t = turtle.Turtle()
#t.shape("turtle")
#x1 = int(input("x1: "))
#y1 = int(input("y1: "))
#x2 = int(input("x2: "))
#y2 = int(input("y2: "))
#dist = ((x1-x2)**2+(y2-y1)**2)**0.5
#t.up()
#t.goto(x1, y1)
#t.down()
#t.goto(x2, y2)
#t.write("점의 길이="+str(dist))
#t._screen.exitonclick()

#7) time(0)을 이용하여 현재 시간의 시와 분 계산
import time
fseconds = time.time()
total_sec = int(fseconds)
total_min = total_sec // 60
minute = total_min % 60
total_hour = total_min // 60
hour = total_hour % 24
print("현재 시간(영국 그리니치 시각: "+str(hour)+"시"+str(minute)+"분")

#8) 움직이는 물체의 운동에너지 계산
mass = float(input("물체의 무게를 입력하시오(킬로그램): "))
velocity = float(input("물체의 속도를 입력하시오(미터/초): "))
energy = 0.5 * mass * velocity **2
print("물체는 " + str(energy)+ " (줄)의 에너지를 가지고 있다.")
# Out:
# x: 5
# y: 6
# 두 수의 합:  11
# 두 수의 차:  -1
# 두 수의 곱:  30
# 두 수의 평균:  5.5
# 큰 수:  6
# 직은 수:  5
# r: 45
# h: 8
# 원기둥의 부피:  50893.790400000005
# 정수를 입력하시오: 45
# 자리수의 합:  9
# x1: 7
# y1: 5
# x2: 6
# y2: 2
# 두 점 사이의 거리= 3.1622776601683795
# 현재 시간(영국 그리니치 시각: 6시40분
# 물체의 무게를 입력하시오(킬로그램): 12
# 물체의 속도를 입력하시오(미터/초): 5
# 물체는 150.0 (줄)의 에너지를 가지고 있다.

# %%
#연습문제4장

#1) 수식 수정하기
#'나는 ' + 12 + '개의 사과를 먹었다.'
#'나는 ' + str(12) + '개의 사과를 먹었다.'


#2) 수식 계산하기
print('apple' + 'grape')
print('apple'*3)

#3) 입력받은 문자열 중 처음 2 글자와 마지막 2 글자를 추출한 후 합쳐서 출력
str = input("문자열을 입력하시오: ")
s = str[0:2] + str[-2:]
print(s)

#4) 문자열 뒤에 "하는 중"을 붙이는 프로그램 작성
s=input("문자열을 입력하시오: ")
s += "하는 중"
print(s)

#5) 기호 안에 문자열 삽입
str=input("기호를 입력하시오: ")
word=input("중간에 삽인할 문자열을 입력하시오: ")
s = str[:1] + word + str[1:]
print(s)

#6) 리스트 안의 숫자를 꺼내 합계를 계산
lista = [1, 2, 3, 4]
sum = 0
sum = lista[0] + lista[1] + lista[2] + lista[3]
print("리스트= ", lista)
print("리스트 숫자들의 합 = ", sum)

#7~8은 터틀 그래픽이라 colab으로 실행 불가

#7) 3가지 색상을 리스트에 저장하였다가 하나씩 꺼내서 그 색으로 채워진 원을 그리는 프로그램 작성
#import turtle
#t = turtle.Turtle()
#t.shape("turtle")
#lista = [ ]
#color = input("색상 #1을 입력하시오: ")
#lista.append(color)
#color = input("색상 #2을 입력하시오: ")
#lista.append(color)
#color = input("색상 #3을 입력하시오: ")
#lista.append(color)
#t.fillcolor(lista[0])
#t.begin_fill()
#t.dirdle(50)
#t.end_fill()
#t.up()
#t.goto(100,0)
#t.down()
#t.fillcolor(lista[1])
#t.begin_fill()
#t.dirdle(50)
#t.end_fill()
#t.up()
#t.goto(200,0)
#t.down()
#t.fillcolor(lista[2])
#t.begin_fill()
#t.dirdle(50)
#t.end_fill()
#t._screen.exitonclick()

#8) 3개의 좌표를 리스트에 저장해 그 좌표로 거북이가 이동하는 프로그램 작성
#import turtle
#t = turtle.Turtle
#t.shape("turtle")
#lista = [ ]
#lista.append(int(input("x1: ")))
#lista.append(int(input("y1: ")))
#lista.append(int(input("x2: ")))
#lista.append(int(input("y2: ")))
#lista.append(int(input("x3: ")))
#lista.append(int(input("y3: ")))
#t.goto(lista[0], lista[1])
#t.goto(lista[2], lista[3])
#t.goto(lista[4], lista[5])
#t._screen.exitonclick()
# Out:
# applegrape
# appleappleapple
# 문자열을 입력하시오: 빅토리아케이크
# 빅토이크
# 문자열을 입력하시오: 과제
# 과제하는 중
# 기호를 입력하시오: []
# 중간에 삽인할 문자열을 입력하시오: 1234
# [1234]
# 리스트=  [1, 2, 3, 4]
# 리스트 숫자들의 합 =  10

# %%
#연습문제5장

#1) 프로그램 출력
age = 20
if age < 20:
  print('20살 미만')
else:
  print('20살 이상')

#2) 1번 문제에서 age가 30이상이고 50 이하인 것을 체크
age = 20
if age >=30 and age <= 50:
  print('30살 이상이고 50살 이하')

#3) 온도를 질문하고 그에 맞는 옷 추천하는 프로그램 작성
temp = int(input("현재 온도를 입력하시오: "))
if temp >= 25:
  print("반바지를 입으세요.")
else:
  print("긴바지를 입으세요.")

#4) 성적 산출 프로그램 작성
score = int(input("성적을 입력하시오: "))
if score >=90:
  print("A학점입니다.")
elif score >= 80:
  print("B학점입니다.")
elif score >= 70:
  print("C학점입니다.")
elif score >= 60:
  print("D학점입니다.")
else:
  print("F학점입니다.")

#5) 1~100 숫자를 사용하는 뺄셈 문제 생성 후 사용자의 답이 올바른지 검사하는 프로그램 작성
import random
x = random.randint(1,100)
y = random.randint(1,100)

answer = int(input(str(x) + "-" + str(y) + "="))
if answer == x - y:
  print("맞았습니다.")
else:
    print("틀렸습니다.")

#6) 정수를 받아 그 정수가 2와 3으로 나누어떨어질 수 있는지 출력
n = int(input("정수를 입력하시오: "))
if n%2==0 and n%3==0:
  print("2와 3으로 나누어 떨어집니다.")
else:
  print("2와 3으로 나누어 떨어지지 않습니다.")

#7) 2자리 수로 당첨번호가 이루어진 복권 당첨 번호를 난수로 생성한 후 사용자의 입력에 따라 상금이 얼마인지 출력하는 프로그램 작성
import random
solution = random.randint(0, 99)
user = int(input("복권번호를 입력하시오(0에서 99사이: "))
digit1 = solution // 10
digit2 = solution % 10
u_digit1 = user // 10
u_digit2 = user % 10
print("당첨번호는", solution, "입니다.")
if (digit1 == u_digit1 and digit2 == u_digit2):
  print("상금은 100만원입니다.")
elif (digit1 == u_digit1
      or digit1 == u_digit2
      or digit2 == u_digit1
      or digit2 == u_digit2):
  print("상금은 50만원입니다")
else:
  print("상금은 없습니다.")

#8은 터틀 그래픽이라 colab으로 실행 불가

#8) 2개의 원에 대한 정보를 받아 원을 그리고 큰원 안에 작은 원이 포함되는지 판단하는 프로그램 작성
#import turtle
#t = turtle.Turtle()
#t.shape("turtle")
#x1 = int(input("큰 원의 중심좌표 x1: "))
#x1 = int(input("큰 원의 중심좌표 x1: "))
#x1 = int(input("큰 원의 중심좌표 x1: "))
# Out:
# 20살 이상
# 현재 온도를 입력하시오: 23
# 긴바지를 입으세요.
# 성적을 입력하시오: 45
# F학점입니다.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-5c99b110801a> in <module>()
#      38 y = random.randint(1,100)
#      39
# ---> 40 answer = int(input(str(x) + "-" + str(y) + "="))
#      41 if answer == x - y:
#      42   print("맞았습니다.")
#
# TypeError: 'str' object is not callable
