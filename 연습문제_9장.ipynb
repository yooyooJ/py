# %% [markdown]
# <a href="https://colab.research.google.com/github/yooyooJ/py/blob/main/%EC%97%B0%EC%8A%B5%EB%AC%B8%EC%A0%9C_9%EC%9E%A5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#연습문제 9장

#연습문제 9-1
alist = []
sum = 0
for i in range(5):
  i = int(input("정수를 입력하시오: "))
  alist.append(i)
for i in alist:
  sum+= i
avg = sum/len(alist)
print("평균=", avg)

#연습문제 9-2
import random
counters = [0, 0, 0, 0, 0, 0]
for i in range(1000):
  value = random.randint(0,5)
  counters[value] = counters[value] + 1
for i in range(6):
  print("주사위가 ", i+1, "인 경우는 ", counters[i], "변")

#연습문제 9-3
contacts = { }
while True:
  name = input("(입력모드)이름을 입력하시오: ")
  if not name:
    break;
  tel = input("전화번호를 입력하시오: ")
  contacts[name] = tel
while True:
  name = input("(검색모드)이름을 입력하시오: ")
  if name in contacts :
    print(name, "의 전화번호는", contacts[name], "입니다,")
  if not name:
    break;

#연습문제 9-4 (turtle grapic)
#import turtle
#import random
#t = turtle.Turtle
#t.shape("turtle")
#def draw_square(x,y,c):
#   t.up()
#   t.goto(x,y)
#   t.down()
#   t.color("black",c)
#   t.begin_fill()
#   t.forward(100)
#   t.left(90)
#   t.forward(100)
#   t.left(90)
#   t.forward(100)
#   t.left(90)
#   t.forward(100)
#   t.left(90)
#   t.end_fill()
#for c in ["yellow", "red", "purple", "blue"]:
#   x = random.randint(-100,100)
#   y = random.randint(-100,100)
#   draw_square(x,y,c)

#연습문제 9-5 (turtle grapic)
#import turtle
#import random
#t = turtle.Turtle()
#s = turtle.Screen()
#def draw_shape(t,c,length,sides,x,y):
#   t.up()
#   t.goto(x,y)
#   t.down()
#   t.fillcolor(c)
#   angle = 360.0/sides
#   t.begin_fill()
#   for dist in range(sides):
#     t.forward(length)
#     t.left(angle)
#   t.end_fill()
#for i in range(10):
#   color = random.choice(['white', 'yellow', 'blue', 'skyblue', 'orange', 'green'])
#   side_length = random.randint(10,100)
#   sides = random.randint(3,10)
#   x = random.randint(-200,200)
#   y = random.randint(-200,200)
#   draw_shape(t,color,side_length,sides,x,y)

#연습문제 9-6 (turtle grapic)
#import turtle
#import random
#t = tuetle.Turtle()
#s = turtle.Screen()
#s.bgcolor("black")
#def draw_star(aturtle, color, side_length, x, y)
#   aturtle.color(color)
#   aturtle.begin_fill()
#   aturtle.prnup()
#   aturtle.goto(x,y)
#   aturtle.pendown()
#   for i in range(5):
#     aturtle.forward(side_length)
#     aturtle.right(144)
#     aturtle.forward(side_length)
#   aturtle.end_fill()
#for i in range(20):
#   color = random.choice(['white', 'yellow', 'blue', 'skyblue', 'orange', 'green'])
#   side_length = random.randint(10,100)
#   x = random.randint(-200,200)
#   y = random.randint(-200,200)
#   dtaw_star(t, color, side_length, x, y)

#연습문제 9-7
domains = {"kr":"대한민국", "us":"미국", "jp":"일본", "de":"독일", "sk":"슬로바키아","hu":"헝가리","no":"노르웨이"}
for k, v in domains.items():
  print(k,": ",v)

#연습문제 9-8
problems = {'파이썬': '최근에 가장 떠오르는 프로그래밍 언어', '변수': '데이터를 저장하는 메모리 공간', '함수': '작업을 수행하는 문장들의 집합에 이름을 붙인것', '리스트': '서로 관련이 없는 항목들의 모임',}
def show_words(problems):
  display_message = ""
  i=1
  for word in problems.keys():
    display_message += "("+str(i)+")"
    display_message += word + " "
    i+=1
  print(display_message)
for meaning in problems.values():
  print("다음은 어떤 단어에 대한 설명일까요? ")
  print("\""+meaning+"\"")
  correct = False
  while not correct:
    show_words(problems)
    guessed_word = input("")
    if problems[guessed_word] == meaning:
      print("정답입니다. !")
      correct = True
    else:
      print("정답이 아닙니다.")
# Out:
# 정수를 입력하시오: 9
# 정수를 입력하시오: 7
# 정수를 입력하시오: 5
# 정수를 입력하시오: 3
# 정수를 입력하시오: 1
# 평균= 5.0
# 주사위가  1 인 경우는  168 변
# 주사위가  2 인 경우는  164 변
# 주사위가  3 인 경우는  172 변
# 주사위가  4 인 경우는  173 변
# 주사위가  5 인 경우는  158 변
# 주사위가  6 인 경우는  165 변
# (입력모드)이름을 입력하시오: abx
# 전화번호를 입력하시오: 123
# (입력모드)이름을 입력하시오:
# (검색모드)이름을 입력하시오: abx
# abx 의 전화번호는 123 입니다,
# (검색모드)이름을 입력하시오:
# kr :  대한민국
# us :  미국
# jp :  일본
# de :  독일
# sk :  슬로바키아
# hu :  헝가리
# no :  노르웨이
# 다음은 어떤 단어에 대한 설명일까요?
# "최근에 가장 떠오르는 프로그래밍 언어"
# (1)파이썬 (2)변수 (3)함수 (4)리스트
# 파이썬
# 정답입니다. !
# 다음은 어떤 단어에 대한 설명일까요?
# "데이터를 저장하는 메모리 공간"
# (1)파이썬 (2)변수 (3)함수 (4)리스트
# 변수
# 정답입니다. !
# 다음은 어떤 단어에 대한 설명일까요?
# "작업을 수행하는 문장들의 집합에 이름을 붙인것"
# (1)파이썬 (2)변수 (3)함수 (4)리스트
# 함수
# 정답입니다. !
# 다음은 어떤 단어에 대한 설명일까요?
# "서로 관련이 없는 항목들의 모임"
# (1)파이썬 (2)변수 (3)함수 (4)리스트
# 리스트
# 정답입니다. !
