# %% [markdown]
# <a href="https://colab.research.google.com/github/yooyooJ/py/blob/main/%EB%8F%84%EC%A0%84%EB%AC%B8%EC%A0%9C_1~5_2100477_%ED%95%9C%EC%9C%A0%EC%A0%95.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#도전문제.Chapter1

#도전문제1-1
print("안녕하세요.")

#도전문제1-2
print("programming에 입문하신 것을 축하드립니다.")

#도전문제-3
print(3.141592*10.0*10.0)

#도전문제1-4
print((1/100)*1234)

#도전문제1-5~7은 turtle grapic


#도전문제.Chapter2

#도전문제2-1
x = 7
y = 6
print(x+y)

#도전문제2-2
x = '7'
y = '6'
print(x+y)

#도전문제2-3은 turtle grapic

#도전문제 2-4 (사용자로부터 2개의 정수를 받아 사칙연산 프로그램 작성)
x = int(input("첫 번째 정수를 입력하시오: "))
y = int(input("두 번째 정수를 입력하시오: "))

print(x, " + ", y, " = ", x + y) #덧셈
print(x, " - ", y, " = ", x - y) #뺄셈
print(x, " * ", y, " = ", x * y) #곱셈
print(x, " / ", y, " = ", x / y) #나눗셈


#도전문제.Chapter3

#도전문제3-1(적자인지, 흑자인지 이익계산)
total = 100000 #총 재료비용
americano_price = 2000
cafelatte_price = 3000
capucino_price = 3500

americanos = int(input("아메리카노 판매 개수: "))
cafelattes = int(input("카페라테 판매 개수: "))
capucinos = int(input("카푸치노 판매 개수: "))

sales = americanos * americano_price
sales = sales + cafelattes * cafelatte_price
sales = sales + capucinos * capucino_price
print("총 매출은", sales, "입니다.")

if (total < sales):
   print("흑자입니다.")
else:
  print("적자입니다.")

#도전문제3-2 (섭씨온도를 화씨온도로 변환)
ctemp = int(input("섭씨온도: "))
ftemp = 9/5*ctemp+32
print("화씨온도: ",ftemp)

#도전문제3-3 (자판기가 50원, 10원짜리 동전도 거슬러 줄 수 있다면~)
money = int(input("투입할 돈: "))
price = int(input("물건 값: "))

change = money - price
print("거스름돈: ",change)
coin500s = change // 500 #500으로 나누어서 몫이 500원짜리의 개수
change = change % 500 #500으로 나눈 나머지를 계산한다.
coin100s = change // 100 #100으로 나누어서 몫이 100원 짜리의 개수
change = change % 100 #100으로 나눈 나머지를 계산한다.
coin50s = change // 50 #50으로 나누어서 몫이 500원짜리의 개수
change = change % 50 #50으로 나눈 나머지를 계산한다.
coin10s = change // 10 #10으로 나누어서 몫이 500원짜리의 개수
change = change % 10 #10으로 나눈 나머지를 계산한다.

print("500원 동전의 개수: ", coin500s)
print("100원 동전의 개수: ", coin100s)
print("50원 동전의 개수: ", coin50s)
print("10원 동전의 개수: ", coin10s)

#도전문제3-4 (다음 프로그램 코드에 주석을 붙여보자)
money = int(input("투입한 돈: ")) #변수 money를 선언하고 정수형으로 받는다
price = int(input("물겁 값: ")) #변수 price를 선언하고 정수로 받는다

change = money - price #거스름돈을 계산한다
coin500s = change // 500 #500으로 나누어서 몫이 500원짜리의 개수이다
change = change % 500 #500으로 나눈 나머지를 계산한다
coin100s = change // 100 #100으로 나누어서 몫이 100원짜리의 개수이다

print("500원 동전의 개수: ", coin500s) #거슬러줄 500원짜리의 개수를 출력한다
print("100원 동전의 개수: ", coin100s) #거슬리줄 100원짜리의 개수를 출력한다


#도전문제.Chapter4

#도전문제4-1은 turtle grapic

#도전문제4-2 (사용자에게 질문하고 답변하기)
print("안녕하세요?")
name = input("이름이 어떻게 되시나요?")
print("만나서 반갑습니다."+name+"씨")
print("이름의 길이는 다음과 같군요: ", end = " ")
print(len(name))
age = int(input("나이가 어떻게 되나요?"))
print("내년이면 ",str(age+1),"이 되시는군요.")
hobby = input("취미가 무엇인가요?")
print("네 저도 "+hobby+"좋아합니다.")

#도전문제4-3 (날짜를 월/일/연도 순으로 출력하기)
year = input("오늘의 연도를 입력하시오: ")
month = input("오늘의 월을 입력하시오: ")
date = input("오늘의 일을 입력하시오: ")

print(month+"/"+date+"/"+year)

#도전문제4-4 (str을 사용하지 않고 쉼표를 이용하여 변수와 문자열 동시 출력)
import time

now = time.time()
thisYear = int(1970 + now//(365*24*2600))

print("올해는 ", thisYear,"입니다.")
age = int(input("몇 살이신지요? "))
print("2050년에는 ",(age+2050-thisYear),"살 이시군요.")


#도전문제.Chapter5

#도전문제5-1 (15세 이상 관람가 영화 안내)
age = int(input("나이를 입력하시오: "))
if age >= 15:
  print("이 영화를 보실 수 있습니다. 영화의 가격은 10000원입니다.")
else:
  print("이 영화를 보실 수 없습니다. 다음 영화를 보시겠어요?")

#도전문제5-2는 turtle grapic

#도전문제5-3 (주사위 던지기 게임)
import random

print("주사위 던지기 게임을 시작합니다.")
dice = random.randrange(6)+1
print("주사위 눈은 "+str(dice)+"입니다.")
print("게임이 종료되었습니다.")

#도전문제5-4
import random
time = random.randint(1,24)
print("좋은 아침입니다. 지금 시각은 "+str(time)+"시 입니다.")

sunny = random.choice([True,False])
if sunny:
  print("현재 날씨가 화창합니다.")
else:
  print("현재 날씨가 화창하지 않습니다.")
#종달새가 노래를 할 것인지 판단
if time >= 6 and time <9 and True:
  print("종달새가 노래를 한다.")
elif time >= 14 and time <16 and True:
  print("종달새가 노래를 한다.")
else:
  print("종달새가 노래를 하지 않는다.")

#도전문제5-5 (아이디 검사 -> 패스워드 검사)
id = "ilivepython"
pw = "123456"
s = input("아이디를 입력하시오: ")
if s == id:
  p = input("패스워드를 입력하시오: ")
  if p == pw:
    print("환영합니다.")
  else:
    print("비밀번호가 잘못되었습니다.")
else:
  print("아이디를 찾을 수 없습니다.")

#도전문제5-5 (게임 작성)
import random

options = ["왼쪽 상단","왼쪽 하단","중앙","오른쪽 상단","오른쪽 하단"]
computer_choice = random.choice(options)
user_choice = input("어디를 수비하시겠어요?(왼쪽 상단, 왼쪽 하단, 중앙, 오른쪽 상단, 오른쪽 하단)")
if computer_choice == user_choice:
  print("수비에 성공하셨습니다.")
else:
  print("페널티 킥이 성공하였습니다.")

#도전문제5-6은 turtle grapic
# Out:
# 안녕하세요.
# programming에 입문하신 것을 축하드립니다.
# 314.1592
# 12.34
# 13
# 76
# 첫 번째 정수를 입력하시오: 3
# 두 번째 정수를 입력하시오: 5
# 3  +  5  =  8
# 3  -  5  =  -2
# 3  *  5  =  15
# 3  /  5  =  0.6
# 아메리카노 판매 개수: 8
# 카페라테 판매 개수: 5
# 카푸치노 판매 개수: 9
# 총 매출은 62500 입니다.
# 적자입니다.
# 섭씨온도: 55
# 화씨온도:  131.0
# 투입할 돈: 200
# 물건 값: 100
# 거스름돈:  100
# 500원 동전의 개수:  0
# 100원 동전의 개수:  1
# 50원 동전의 개수:  0
# 10원 동전의 개수:  0
# 투입한 돈: 5000
# 물겁 값: 3000
# 500원 동전의 개수:  4
# 100원 동전의 개수:  0
# 안녕하세요?
# 이름이 어떻게 되시나요?g
# 만나서 반갑습니다.g씨
# 이름의 길이는 다음과 같군요:  1
# 나이가 어떻게 되나요?56
# 내년이면  57 이 되시는군요.
# 취미가 무엇인가요?bhb
# 네 저도 bhb좋아합니다.
# 오늘의 연도를 입력하시오: 2021
# 오늘의 월을 입력하시오: 11
# 오늘의 일을 입력하시오: 12
# 11/12/2021
# 올해는  2041 입니다.
# 몇 살이신지요? 52
# 2050년에는  61 살 이시군요.
# 나이를 입력하시오: 45
# 이 영화를 보실 수 있습니다. 영화의 가격은 10000원입니다.
# 주사위 던지기 게임을 시작합니다.
# 주사위 눈은 3입니다.
# 게임이 종료되었습니다.
# 좋은 아침입니다. 지금 시각은 8시 입니다.
# 현재 날씨가 화창하지 않습니다.
# 종달새가 노래를 한다.
# 아이디를 입력하시오: 898
# 아이디를 찾을 수 없습니다.
# 어디를 수비하시겠어요?(왼쪽 상단, 왼쪽 하단, 중앙, 오른쪽 상단, 오른쪽 하단)왼
# 페널티 킥이 성공하였습니다.
